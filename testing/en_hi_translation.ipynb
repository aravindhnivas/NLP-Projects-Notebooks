# %%
# Translation
from transformers import AutoTokenizer
from transformers import TFAutoModelForSeq2SeqLM

# %%
# Audio
from transformers import VitsModel, AutoTokenizer
import torch
from IPython.display import Audio
import scipy
import numpy as np

# %%
loc = "/Users/aravindhnivas/Library/CloudStorage/GoogleDrive-aravindhnivas28@gmail.com/My Drive/neon-ai-ml-models/eng-hi/processed"

# %%
tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-hi")
model = TFAutoModelForSeq2SeqLM.from_pretrained(f"{loc}/tf_model/")
# Out:
# All model checkpoint layers were used when initializing TFMarianMTModel.
#
# All the layers of TFMarianMTModel were initialized from the model checkpoint at /Users/aravindhnivas/Library/CloudStorage/GoogleDrive-aravindhnivas28@gmail.com/My Drive/neon-ai-ml-models/eng-hi/processed/tf_model/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFMarianMTModel for predictions without further training.

# %%
input_text  = "Tamil historical novel written by Kalki Krishnamurthy. Written in five volumes, this narrates the story of Arulmozhivarman (later crowned as Rajaraja Chola I), one of the kings of theChola Dynasty during the 10th and 11th centuries.Kalki Krishnamurthy finished the novel after nearly a period of three years and six months of writing and he visited Sri Lanka three times to learn some information to write this novel."

tokenized = tokenizer([input_text], return_tensors='np')
out = model.generate(**tokenized, max_length=128)
print(out)
# Out:
# tf.Tensor(
# [[61949  3093  2686 13965   260   335 11811 14959 14959 43469    40  4490
#    6778    86    11   761   115     5     2    60  4468   428  8927 10949
#   10949  8602    17  1490   240    11  1686    69 12175   917  3085   716
#    4223     6    38   473     5    13     6   207    11  2466     5     2
#      41   932    12  1366  4126     9  1366  4126  2087     6   858     5
#      40     6  2711  6712    20  6080     6   240     2  1231  1000  6080
#       6   240     2  1231  1000  6080     6   207    11   327    89   207
#      11   158    15     5    40     0]], shape=(1, 90), dtype=int32)

# %%
translated = ''
with tokenizer.as_target_tokenizer():
    translated = tokenizer.decode(out[0], skip_special_tokens=True)
    print(translated)
# Out:
# कलिद्रा द्वारा लिखित ऐतिहासिक ऐतिहासिक उपन्यास। पांच खंडों में लिखा गया है, यह यूरमोडोडोबर (जो बाद में राज-ब्रोलाक प्रथम के एक राजा है) के बारे में बताता है, जो 10 से 11वीं और 11वीं सदी के दौरान है। के लगभग छ: महीनों के बाद, तथा तीन महीनों के बाद, तथा तीन महीनों के बारे में उन्होंने इस बारे में बात की है।

# %%
translated
# Out:
# 'Ponnyyon Slyn Sontonn Sonttyyyymyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyyy, के रूप में लिखा गया 20वीं ऐतिहासिक ऐतिहासिक ऐतिहासिक ऐतिहासिक ऐतिहासिक ऐतिहासिक उपन्यास है। पांच खंड में, यह यू.'

# %% [markdown]
# # Hindi TTS

# %%
TTS_model_hindi = VitsModel.from_pretrained("facebook/mms-tts-hin")
tokenizer_hindi = AutoTokenizer.from_pretrained("facebook/mms-tts-hin")
# Out:
# Some weights of the model checkpoint at facebook/mms-tts-hin were not used when initializing VitsModel: ['flow.flows.0.wavenet.in_layers.0.weight_g', 'flow.flows.0.wavenet.in_layers.0.weight_v', 'flow.flows.0.wavenet.in_layers.1.weight_g', 'flow.flows.0.wavenet.in_layers.1.weight_v', 'flow.flows.0.wavenet.in_layers.2.weight_g', 'flow.flows.0.wavenet.in_layers.2.weight_v', 'flow.flows.0.wavenet.in_layers.3.weight_g', 'flow.flows.0.wavenet.in_layers.3.weight_v', 'flow.flows.0.wavenet.res_skip_layers.0.weight_g', 'flow.flows.0.wavenet.res_skip_layers.0.weight_v', 'flow.flows.0.wavenet.res_skip_layers.1.weight_g', 'flow.flows.0.wavenet.res_skip_layers.1.weight_v', 'flow.flows.0.wavenet.res_skip_layers.2.weight_g', 'flow.flows.0.wavenet.res_skip_layers.2.weight_v', 'flow.flows.0.wavenet.res_skip_layers.3.weight_g', 'flow.flows.0.wavenet.res_skip_layers.3.weight_v', 'flow.flows.1.wavenet.in_layers.0.weight_g', 'flow.flows.1.wavenet.in_layers.0.weight_v', 'flow.flows.1.wavenet.in_layers.1.w
# ...

# %%
hindi_txt = 'कल्कि कृष्णमूर्ति द्वारा लिखित तमिल ऐतिहासिक उपन्यास। पांच खंडों में लिखा गया, यह 10वीं और 11वीं शताब्दी के दौरान चोल राजवंश के राजाओं में से एक, अरुलमोझीवर्मन (बाद में राजराजा चोल प्रथम के रूप में ताज पहनाया गया) की कहानी बताता है। कल्कि कृष्णमूर्ति ने लगभग तीन साल और छह महीने की अवधि के बाद उपन्यास को समाप्त किया। लेखन और इस उपन्यास को लिखने के लिए कुछ जानकारी सीखने के लिए उन्होंने तीन बार श्रीलंका का दौरा किया।'


inputs_hindi = tokenizer_hindi(translated, return_tensors="pt")

with torch.no_grad():
    output = TTS_model_hindi(**inputs_hindi).waveform
    
print("Sampling rate:", TTS_model.config.sampling_rate)
print("Number of channels:", output.float().numpy().shape[0])

Audio(output.numpy(), rate=TTS_model.config.sampling_rate)
# Out:
# Sampling rate: 16000
# Number of channels: 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("Sampling rate:", TTS_model.config.sampling_rate)
print("Number of channels:", output.float().numpy().shape[0])

Audio(output.numpy(), rate=TTS_model.config.sampling_rate)
# Out:
# Sampling rate: 16000
# Number of channels: 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# scipy.io.wavfile.write("techno.wav", rate=model.config.sampling_rate, data=output.float().numpy())

# %% [markdown]
# ## Tamil TTS

# %%
TTS_model_tamil = VitsModel.from_pretrained("facebook/mms-tts-tam")
tokenizer_tamil = AutoTokenizer.from_pretrained("facebook/mms-tts-tam")
# Out:
# Some weights of the model checkpoint at facebook/mms-tts-tam were not used when initializing VitsModel: ['flow.flows.0.wavenet.in_layers.0.weight_g', 'flow.flows.0.wavenet.in_layers.0.weight_v', 'flow.flows.0.wavenet.in_layers.1.weight_g', 'flow.flows.0.wavenet.in_layers.1.weight_v', 'flow.flows.0.wavenet.in_layers.2.weight_g', 'flow.flows.0.wavenet.in_layers.2.weight_v', 'flow.flows.0.wavenet.in_layers.3.weight_g', 'flow.flows.0.wavenet.in_layers.3.weight_v', 'flow.flows.0.wavenet.res_skip_layers.0.weight_g', 'flow.flows.0.wavenet.res_skip_layers.0.weight_v', 'flow.flows.0.wavenet.res_skip_layers.1.weight_g', 'flow.flows.0.wavenet.res_skip_layers.1.weight_v', 'flow.flows.0.wavenet.res_skip_layers.2.weight_g', 'flow.flows.0.wavenet.res_skip_layers.2.weight_v', 'flow.flows.0.wavenet.res_skip_layers.3.weight_g', 'flow.flows.0.wavenet.res_skip_layers.3.weight_v', 'flow.flows.1.wavenet.in_layers.0.weight_g', 'flow.flows.1.wavenet.in_layers.0.weight_v', 'flow.flows.1.wavenet.in_layers.1.w
# ...

# %%
tam_input = "பிரைட் அண்ட் ப்ரெஜுடிஸ் என்பது ஆங்கில எழுத்தாளர் ஜேன் ஆஸ்டனின் இரண்டாவது நாவல், இது 1813 இல் வெளியிடப்பட்டது. பழக்கவழக்கங்களின் நாவல், இது புத்தகத்தின் கதாநாயகனான எலிசபெத் பென்னட்டின் பாத்திர வளர்ச்சியைப் பின்பற்றுகிறது, அவர் அவசரத் தீர்ப்புகளின் விளைவுகளைப் பற்றி அறிந்துகொண்டு பாராட்டுகிறார். மேலோட்டமான நன்மைக்கும் உண்மையான நன்மைக்கும் உள்ள வேறுபாடு."

inputs_tamil = tokenizer_tamil(tam_input, return_tensors="pt")

with torch.no_grad():
    output_tam_audio = TTS_model_tamil(**inputs_tamil).waveform
    
print("Sampling rate:", TTS_model.config.sampling_rate)
print("Number of channels:", output.float().numpy().shape[0])

Audio(output_tam_audio.numpy(), rate=TTS_model_tamil.config.sampling_rate)
# Out:
# Sampling rate: 16000
# Number of channels: 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
